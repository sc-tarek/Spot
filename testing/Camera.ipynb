# %% [markdown]
# ## Capture and View Camera Images

# %% [markdown]
# #### Create the SDK object

# %% [markdown]
# All Boston Dynamics API programs start by creating an SDK object with a client name argument. The client name is used to help with debugging, and does not have any semantic information - so use whatever string is helpful for you.

# %%
import bosdyn.client

sdk = bosdyn.client.create_standard_sdk('understanding-spot')

# %% [markdown]
# #### Create a robot object

# %% [markdown]
# To retrieve the robot id like we did in Spot Python SDK Quickstart we’ll first need to create a robot object, using its network address as an argument. In this example, we only create one robot object, but it is possible to create and control multiple robots in the same program with the Boston Dynamics API.

# %%
robot = sdk.create_robot('192.168.80.3')

# %% [markdown]
# #### Services and Authentication

# %% [markdown]
# -- Need to be on the Spot Wifi for this step --
#
# Before robot state can be retrieved, you need to authenticate to the robot. The majority of services require the user to be authenticated - this prevents random network attackers from being able to control the robot or intercept information which might be sensitive.

# %%
robot.authenticate('user', 'hhe262iz9zez')

# %% [markdown]
# Obtain information about Spot:

# %%
state_client = robot.ensure_client('robot-state')

# %%
state_client.get_robot_state()
# Out:
# power_state {
#   motor_power_state: STATE_OFF
#   shore_power_state: STATE_OFF_SHORE_POWER
#   robot_power_state: ROBOT_POWER_STATE_ON
#   payload_ports_power_state: PAYLOAD_PORTS_POWER_STATE_ON
#   wifi_radio_power_state: WIFI_RADIO_POWER_STATE_ON
#   locomotion_charge_percentage {
#     value: 42
#   }
#   locomotion_estimated_runtime {
#     seconds: 2388
#     nanos: 141357421
#   }
# }
# battery_states {
#   identifier: "a2-22b14-001e"
#   charge_percentage {
#     value: 42
#   }
#   estimated_runtime {
#     seconds: 2388
#     nanos: 141357421
#   }
#   current {
#     value: -4.0199999809265137
#   }
#   voltage {
#     value: 51.184001922607422
#   }
#   temperatures: 33.396297454833984
#   temperatures: 33.1185188293457
#   temperatures: 33.159259796142578
#   temperatures: 32.818519592285156
#   temperatures: 32.355556488037109
#   temperatures: 33.537036895751953
#   temperatures: 32.774074554443359
#   temperatures: 32.785186767578125
#   temperatures: 32.896297454833984
#   temperatures: 32.592594146728516
#   status: STATUS_DISCHARGING
# }
# comms_states {
#   timestamp {
#     seconds: 1674651565
#     nanos: 85602641
#   }
#   wifi_state {
#     current_mode: MODE_ACCESS_POINT
#   }
# }
# system_fault_state {
# }
# estop_states {
#   timestamp {
#     seconds: 1674651566
#     nanos: 72919808
#   }
#   name: "hardware_estop"
#   type: TYPE_HARDWARE
#   state: STATE_NOT_ESTOPPED
# }
# estop_states {
#   timestamp {
#     seconds: 1674651566
#     nanos: 72919808
#   }
#   name: "payload_estop"
#   type: TYPE_HARDWARE
#   state: STATE_NOT_ESTOPPED
# }
# estop_states {
#   timestamp {
#     seconds: 1674651566
#     nanos: 72919808
#   }
#   name: "software_estop"
#   type: TYPE_SOFTWARE
#   state: STATE_ESTOPPED
# }
# kinematic_state {
#   joint_states {
#     name: "fl.hx"
#     position {
#       value: 0.546417236328125
#     }
#     velocity {
#       value: -0.0024516647681593895
#     }
#     acceleration {
#       value: 0.90072882175445557
#     }
#     load {
#       value: 1.0975691080093384
#     }
#   }
#   joint_states {
#     name: "fl.hy"
#     position {
#       value: 1.2132576704025269
#     }
#     velocity {
#       value: 0.00769829610362649
#     }
#     acceleration {
#       value: -1.9183056354522705
#     }
#     load {
#       value: -0.78689533472061157
#     }
#   }
#   joint_states {
#     name: "fl.kn"
#     position {
#       value: -2.7833418846130371
#     }
#     velocity {
#       value: 0.052253495901823044
#     }
#     acceleration {
#       value: -6.8478598594665527
#     }
#     load {
#       value: -0.60847342014312744
#     }
#   }
#   joint_states {
#     name: "fr.hx"
#     position {
#       value: -0.52406352758407593
#     }
#     velocity {
#       value: -0.0014136169338598847
#     }
#     acceleration {
#       value: -2.821681022644043
#     }
#     load {
#       value: -1.6401864290237427
#     }
#   }
#   joint_states {
#     name: "fr.hy"
#     position {
#       value: 1.2406352758407593
#     }
#     velocity {
#       value: 0.007756444625556469
#     }
#     acceleration {
#       value: 0.72538483142852783
#     }
#     load {
#       value: -0.80038970708847046
#     }
#   }
#   joint_states {
#     name: "fr.kn"
#     position {
#       value: -2.7952008247375488
#     }
#     velocity {
#       value: 0.0037296181544661522
#     }
#     acceleration {
#       value: 3.0797264575958252
#     }
#     load {
#       value: -0.1597381979227066
#     }
#   }
#   joint_states {
#     name: "hl.hx"
#     position {
#       value: 0.55189496278762817
#     }
#     velocity {
#       value: -0.013455739244818687
#     }
#     acceleration {
#       value: -2.8874058723449707
#     }
#     load {
#       value: 0.20785783231258392
#     }
#   }
#   joint_states {
#     name: "hl.hy"
#     position {
#       value: 1.2544997930526733
#     }
#     velocity {
#       value: 0.0036952865775674582
#     }
#     acceleration {
#       value: 0.10225464403629303
#     }
#     load {
#       value: 1.3754420280456543
#     }
#   }
#   joint_states {
#     name: "hl.kn"
#     position {
#       value: -2.7975718975067139
#     }
#     velocity {
#       value: 0.015095451846718788
#     }
#     acceleration {
#       value: -1.388758659362793
#     }
#     load {
#       value: 0.06636374443769455
#     }
#   }
#   joint_states {
#     name: "hr.hx"
#     position {
#       value: -0.5731579065322876
#     }
#     velocity {
#       value: 0.0023746471852064133
#     }
#     acceleration {
#       value: 1.8369417190551758
#     }
#     load {
#       value: -0.82437270879745483
#     }
#   }
#   joint_states {
#     name: "hr.hy"
#     position {
#       value: 1.2513535022735596
#     }
#     velocity {
#       value: -0.012106049805879593
#     }
#     acceleration {
#       value: -0.35553568601608276
#     }
#     load {
#       value: 0.34197086095809937
#     }
#   }
#   joint_states {
#     name: "hr.kn"
#     position {
#       value: -2.8002996444702148
#     }
#     velocity {
#       value: -0.035505816340446472
#     }
#     acceleration {
#       value: -2.7539749145507812
#     }
#     load {
#       value: -0.089187197387218475
#     }
#   }
#   joint_states {
#     name: "arm0.sh0"
#     position {
#       value: -0.021040916442871094
#     }
#     velocity {
#       value: -0.00012478612188715488
#     }
#     acceleration {
#       value: 0.19981332123279572
#     }
#     load {
#       value: 0.89569151401519775
#     }
#   }
#   joint_states {
#     name: "arm0.sh1"
#     position {
#       value: -3.1333622932434082
#     }
#     velocity {
#       value: -0.0063279788009822369
#     }
#     acceleration {
#       value: -0.038337476551532745
#     }
#     load {
#       value: 0.01225335244089365
#     }
#   }
#   joint_states {
#     name: "arm0.hr0"
#     position {
#     }
#     velocity {
#     }
#     acceleration {
#     }
#     load {
#     }
#   }
#   joint_states {
#     name: "arm0.el0"
#     position {
#       value: 3.1309969425201416
#     }
#     velocity {
#       value: -0.0062222112901508808
#     }
#     acceleration {
#       value: 0.82938873767852783
#     }
#     load {
#       value: 0.0996817871928215
#     }
#   }
#   joint_states {
#     name: "arm0.el1"
#     position {
#       value: 1.5702145099639893
#     }
#     velocity {
#       value: -0.0014692211989313364
#     }
#     acceleration {
#       value: 0.99933606386184692
#     }
#     load {
#       value: -0.07873138040304184
#     }
#   }
#   joint_states {
#     name: "arm0.wr0"
#     position {
#       value: -0.014936327934265137
#     }
#     velocity {
#       value: 0.00021748679864685982
#     }
#     acceleration {
#       value: -0.37506088614463806
#     }
#     load {
#       value: -0.033133689314126968
#     }
#   }
#   joint_states {
#     name: "arm0.wr1"
#     position {
#       value: -1.5683035850524902
#     }
#     velocity {
#       value: 0.019691457971930504
#     }
#     acceleration {
#       value: -0.65310013294219971
#     }
#     load {
#       value: 0.25226002931594849
#     }
#   }
#   joint_states {
#     name: "arm0.f1x"
#     position {
#       value: -0.012310981750488281
#     }
#     velocity {
#       value: 0.012309536337852478
#     }
#     acceleration {
#       value: -2.2947425842285156
#     }
#     load {
#       value: 0.010067637078464031
#     }
#   }
#   acquisition_timestamp {
#     seconds: 1674651566
#     nanos: 72919808
#   }
#   transforms_snapshot {
#     child_to_parent_edge_map {
#       key: "vision"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: 0.0025345981121063232
#             y: 0.0025042891502380371
#             z: 0.0014643967151641846
#           }
#           rotation {
#             x: -0.00023416968178935349
#             y: 0.0056756888516247272
#             z: -0.00032775101135484874
#             w: 0.99998384714126587
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "odom"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: -0.12172491103410721
#             y: -0.041275598108768463
#             z: -0.372758150100708
#           }
#           rotation {
#             x: -0.0038202232681214809
#             y: 0.0042040660046041012
#             z: -0.6416739821434021
#             w: 0.76695650815963745
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "link_wr1"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: 0.35661861300468445
#             y: -0.0013598357327282429
#             z: 0.26673966646194458
#           }
#           rotation {
#             x: 0.00095165276434272528
#             y: -0.0012042002053931355
#             z: -0.017986496910452843
#             w: 0.99983704090118408
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "hand"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: 0.55206149816513062
#             y: -0.0083943763747811317
#             z: 0.26720389723777771
#           }
#           rotation {
#             x: 0.00095165276434272528
#             y: -0.0012042002053931355
#             z: -0.017986496910452843
#             w: 0.99983704090118408
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "gpe"
#       value {
#         parent_frame_name: "odom"
#         parent_tform_child {
#           position {
#             x: -0.019722780212759972
#             y: 0.12289535999298096
#             z: 0.37532564997673035
#           }
#           rotation {
#             x: 0.012466439045965672
#             y: -0.093162350356578827
#             z: -0.0011665681377053261
#             w: 0.99557220935821533
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "flat_body"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#           }
#           rotation {
#             x: -0.00023231642262544483
#             y: 0.0056757647544145584
#             z: -1.281402433050971e-006
#             w: 0.99998390674591064
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "body"
#       value {
#         parent_tform_child {
#           position {
#           }
#           rotation {
#             w: 1
#           }
#         }
#       }
#     }
#   }
#   velocity_of_body_in_vision {
#     linear {
#       x: 3.3341817470500246e-005
#       y: -0.00048705079825595021
#       z: 0.0001036622779793106
#     }
#     angular {
#       x: -9.4977905973792076e-005
#       y: 0.0034420923329889774
#       z: -0.0043625263497233391
#     }
#   }
#   velocity_of_body_in_odom {
#     linear {
#       x: 0.00048525529564358294
#       y: -5.3455558372661471e-005
#       z: 0.00010366225615143776
#     }
#     angular {
#       x: -0.0034044890198856592
#       y: 0.00051621370948851109
#       z: -0.0043625263497233391
#     }
#   }
# }
# behavior_fault_state {
# }
# foot_state {
#   foot_position_rt_body {
#     x: 0.36634942889213562
#     y: 0.23336802423000336
#     z: -0.079770617187023163
#   }
#   contact: CONTACT_LOST
# }
# foot_state {
#   foot_position_rt_body {
#     x: 0.36231192946434021
#     y: -0.23031610250473022
#     z: -0.08161916583776474
#   }
#   contact: CONTACT_LOST
# }
# foot_state {
#   foot_position_rt_body {
#     x: -0.23550638556480408
#     y: 0.23253363370895386
#     z: -0.0767318457365036
#   }
#   contact: CONTACT_LOST
# }
# foot_state {
#   foot_position_rt_body {
#     x: -0.23491725325584412
#     y: -0.233486607670784
#     z: -0.071950934827327728
#   }
#   contact: CONTACT_LOST
# }
# manipulator_state {
#   gripper_open_percentage: 0.78414082527160645
#   estimated_end_effector_force_in_hand {
#     x: 14.204941749572754
#     y: -1.7647650241851807
#     z: 15.276959419250488
#   }
#   stow_state: STOWSTATE_STOWED
#   velocity_of_hand_in_vision {
#     linear {
#       x: -9.7996744443662465e-005
#       y: -0.0028286678716540337
#       z: 0.0035790535621345043
#     }
#     angular {
#       x: 0.017856229096651077
#       y: -0.00977090559899807
#       z: -0.0040290094912052155
#     }
#   }
#   velocity_of_hand_in_odom {
#     linear {
#       x: 0.0027665828820317984
#       y: -0.00059748231433331966
#       z: 0.0035790533293038607
#     }
#     angular {
#       x: 0.0127792377024889
#       y: 0.015843190252780914
#       z: -0.0040290094912052155
#     }
#   }
#   carry_state: CARRY_STATE_NOT_CARRIABLE
# }
# terrain_state {
# }

# %%
from bosdyn.client.image import ImageClient

image_client = robot.ensure_client(ImageClient.default_service_name)
sources = image_client.list_image_sources()
[source.name for source in sources]
# Out:
# ['back_depth',
#  'back_depth_in_visual_frame',
#  'back_fisheye_image',
#  'frontleft_depth',
#  'frontleft_depth_in_visual_frame',
#  'frontleft_fisheye_image',
#  'frontright_depth',
#  'frontright_depth_in_visual_frame',
#  'frontright_fisheye_image',
#  'hand_color_image',
#  'hand_color_in_hand_depth_frame',
#  'hand_depth',
#  'hand_depth_in_hand_color_frame',
#  'hand_image',
#  'left_depth',
#  'left_depth_in_visual_frame',
#  'left_fisheye_image',
#  'right_depth',
#  'right_depth_in_visual_frame',
#  'right_fisheye_image']

# %%
image_response = image_client.get_image_from_sources(["frontleft_fisheye_image"])[0]
from PIL import Image
import io
image = Image.open(io.BytesIO(image_response.shot.image.data))
image.show()
