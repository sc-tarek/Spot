# %% [markdown]
# ## Setup and Command Spot to Move

# %% [markdown]
# #### Create objects

# %% [markdown]
# All Boston Dynamics API programs start by creating an SDK object with a client name argument. The client name is used to help with debugging, and does not have any semantic information - so use whatever string is helpful for you.

# %%
import bosdyn.client

sdk = bosdyn.client.create_standard_sdk('understanding-spot')

# %% [markdown]
# To retrieve the robot id like we did in Spot Python SDK Quickstart we’ll first need to create a robot object, using its network address as an argument. In this example, we only create one robot object, but it is possible to create and control multiple robots in the same program with the Boston Dynamics API.

# %%
robot = sdk.create_robot('192.168.80.3')

# %% [markdown]
# #### Services and Authentication

# %% [markdown]
# -- Need to be on the Spot Wifi for this step --
#
# Before robot state can be retrieved, you need to authenticate to the robot. The majority of services require the user to be authenticated - this prevents random network attackers from being able to control the robot or intercept information which might be sensitive.

# %%
robot.authenticate('user', 'hhe262iz9zez')

# %% [markdown]
# Obtain information about Spot:

# %%
state_client = robot.ensure_client('robot-state')

# %%
state_client.get_robot_state()
# Out:
# power_state {
#   motor_power_state: STATE_OFF
#   shore_power_state: STATE_OFF_SHORE_POWER
#   robot_power_state: ROBOT_POWER_STATE_ON
#   payload_ports_power_state: PAYLOAD_PORTS_POWER_STATE_ON
#   wifi_radio_power_state: WIFI_RADIO_POWER_STATE_ON
#   locomotion_charge_percentage {
#     value: 69
#   }
#   locomotion_estimated_runtime {
#     seconds: 3924
#     nanos: 225830078
#   }
# }
# battery_states {
#   identifier: "a2-22b14-001e"
#   charge_percentage {
#     value: 69
#   }
#   estimated_runtime {
#     seconds: 3924
#     nanos: 225830078
#   }
#   current {
#     value: -3.7320001125335693
#   }
#   voltage {
#     value: 53.760002136230469
#   }
#   temperatures: 33.907405853271484
#   temperatures: 33.548149108886719
#   temperatures: 33.518520355224609
#   temperatures: 33.270370483398437
#   temperatures: 32.677776336669922
#   temperatures: 33.933334350585938
#   temperatures: 33.022220611572266
#   temperatures: 33.014816284179688
#   temperatures: 33.311111450195313
#   temperatures: 33.229629516601563
#   status: STATUS_DISCHARGING
# }
# comms_states {
#   timestamp {
#     seconds: 1674725733
#     nanos: 938732145
#   }
#   wifi_state {
#     current_mode: MODE_ACCESS_POINT
#   }
# }
# system_fault_state {
# }
# estop_states {
#   timestamp {
#     seconds: 1674725734
#     nanos: 711630848
#   }
#   name: "hardware_estop"
#   type: TYPE_HARDWARE
#   state: STATE_ESTOPPED
# }
# estop_states {
#   timestamp {
#     seconds: 1674725734
#     nanos: 711630848
#   }
#   name: "payload_estop"
#   type: TYPE_HARDWARE
#   state: STATE_NOT_ESTOPPED
# }
# estop_states {
#   timestamp {
#     seconds: 1674725734
#     nanos: 711630848
#   }
#   name: "software_estop"
#   type: TYPE_SOFTWARE
#   state: STATE_ESTOPPED
# }
# kinematic_state {
#   joint_states {
#     name: "fl.hx"
#     position {
#       value: 0.51954495906829834
#     }
#     velocity {
#       value: 0.0027506961487233639
#     }
#     acceleration {
#       value: -1.8583499193191528
#     }
#     load {
#       value: 0.766244649887085
#     }
#   }
#   joint_states {
#     name: "fl.hy"
#     position {
#       value: 1.4269182682037354
#     }
#     velocity {
#       value: 0.019081771373748779
#     }
#     acceleration {
#       value: 0.0954810082912445
#     }
#     load {
#       value: 2.0032892227172852
#     }
#   }
#   joint_states {
#     name: "fl.kn"
#     position {
#       value: -2.7986977100372314
#     }
#     velocity {
#       value: 0.017922142520546913
#     }
#     acceleration {
#       value: 0.53837472200393677
#     }
#     load {
#       value: 0.2053932398557663
#     }
#   }
#   joint_states {
#     name: "fr.hx"
#     position {
#       value: -0.51837277412414551
#     }
#     velocity {
#       value: -0.0078640291467309
#     }
#     acceleration {
#       value: 4.9885635375976562
#     }
#     load {
#       value: -1.2531663179397583
#     }
#   }
#   joint_states {
#     name: "fr.hy"
#     position {
#       value: 1.4313756227493286
#     }
#     velocity {
#       value: -0.0041177584789693356
#     }
#     acceleration {
#       value: 3.6223666667938232
#     }
#     load {
#       value: 1.3234968185424805
#     }
#   }
#   joint_states {
#     name: "fr.kn"
#     position {
#       value: -2.7975177764892578
#     }
#     velocity {
#       value: -0.01558879017829895
#     }
#     acceleration {
#       value: 7.7166924476623535
#     }
#     load {
#       value: 0.1682489812374115
#     }
#   }
#   joint_states {
#     name: "hl.hx"
#     position {
#       value: 0.56892120838165283
#     }
#     velocity {
#       value: 0.01159506943076849
#     }
#     acceleration {
#       value: 1.3716249465942383
#     }
#     load {
#       value: -0.97361183166503906
#     }
#   }
#   joint_states {
#     name: "hl.hy"
#     position {
#       value: 1.4088536500930786
#     }
#     velocity {
#       value: 0.0041824346408247948
#     }
#     acceleration {
#       value: -0.53545534610748291
#     }
#     load {
#       value: 1.8118351697921753
#     }
#   }
#   joint_states {
#     name: "hl.kn"
#     position {
#       value: -2.7994096279144287
#     }
#     velocity {
#       value: -0.00778429489582777
#     }
#     acceleration {
#       value: 9.2332267761230469
#     }
#     load {
#       value: 0.43886566162109375
#     }
#   }
#   joint_states {
#     name: "hr.hx"
#     position {
#       value: -0.56761550903320313
#     }
#     velocity {
#       value: 0.0094276377931237221
#     }
#     acceleration {
#       value: -3.0143630504608154
#     }
#     load {
#       value: 1.3757877349853516
#     }
#   }
#   joint_states {
#     name: "hr.hy"
#     position {
#       value: 1.4227409362792969
#     }
#     velocity {
#       value: 1.3033056347921956e-005
#     }
#     acceleration {
#       value: -1.8817292451858521
#     }
#     load {
#       value: 2.00142765045166
#     }
#   }
#   joint_states {
#     name: "hr.kn"
#     position {
#       value: -2.7999958992004395
#     }
#     velocity {
#       value: -0.010825417935848236
#     }
#     acceleration {
#       value: -0.47639212012290955
#     }
#     load {
#       value: 0.020869031548500061
#     }
#   }
#   joint_states {
#     name: "arm0.sh0"
#     position {
#       value: -0.004322052001953125
#     }
#     velocity {
#       value: -0.0081037525087594986
#     }
#     acceleration {
#       value: -0.85800427198410034
#     }
#     load {
#       value: 0.86813181638717651
#     }
#   }
#   joint_states {
#     name: "arm0.sh1"
#     position {
#       value: -3.127204418182373
#     }
#     velocity {
#       value: -0.00055782037088647485
#     }
#     acceleration {
#       value: -0.053277477622032166
#     }
#     load {
#       value: 2.9434607028961182
#     }
#   }
#   joint_states {
#     name: "arm0.hr0"
#     position {
#     }
#     velocity {
#     }
#     acceleration {
#     }
#     load {
#     }
#   }
#   joint_states {
#     name: "arm0.el0"
#     position {
#       value: 3.1314282417297363
#     }
#     velocity {
#       value: 0.012841800227761269
#     }
#     acceleration {
#       value: -1.8506882190704346
#     }
#     load {
#       value: 2.0800113677978516
#     }
#   }
#   joint_states {
#     name: "arm0.el1"
#     position {
#       value: 1.5701688528060913
#     }
#     velocity {
#       value: -0.0057509155012667179
#     }
#     acceleration {
#       value: 0.2737792432308197
#     }
#     load {
#       value: -0.045541901141405106
#     }
#   }
#   joint_states {
#     name: "arm0.wr0"
#     position {
#       value: 0.00028467178344726563
#     }
#     velocity {
#       value: -0.012448194436728954
#     }
#     acceleration {
#       value: 0.2968372106552124
#     }
#     load {
#       value: -0.023980537429451942
#     }
#   }
#   joint_states {
#     name: "arm0.wr1"
#     position {
#       value: -1.5704951286315918
#     }
#     velocity {
#       value: 0.0038121102843433619
#     }
#     acceleration {
#       value: -2.7265653610229492
#     }
#     load {
#       value: 0.25404027104377747
#     }
#   }
#   joint_states {
#     name: "arm0.f1x"
#     position {
#       value: -0.011555910110473633
#     }
#     velocity {
#       value: 0.0094889979809522629
#     }
#     acceleration {
#       value: -0.798006534576416
#     }
#     load {
#       value: 0.041414979845285416
#     }
#   }
#   acquisition_timestamp {
#     seconds: 1674725734
#     nanos: 711630848
#   }
#   transforms_snapshot {
#     child_to_parent_edge_map {
#       key: "vision"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: -5.2014884948730469
#             y: 8.4210004806518555
#             z: -0.034209355711936951
#           }
#           rotation {
#             x: -0.0048473100177943707
#             y: -0.0020438802894204855
#             z: -0.99997407197952271
#             w: -0.004927532747387886
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "odom"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: -4.985170841217041
#             y: 8.6426916122436523
#             z: -1.7140030860900879
#           }
#           rotation {
#             x: -0.0040671252645552158
#             y: 0.0033365173730999231
#             z: -0.47031736373901367
#             w: 0.88248169422149658
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "link_wr1"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: 0.35714757442474365
#             y: -0.00028157304041087627
#             z: 0.26616612076759338
#           }
#           rotation {
#             x: -0.00015827255265321583
#             y: 0.0021123222541064024
#             z: -0.0020183396991342306
#             w: 0.99999570846557617
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "hand"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: 0.55271422863006592
#             y: -0.0010711539071053267
#             z: 0.26534003019332886
#           }
#           rotation {
#             x: -0.00015827255265321583
#             y: 0.0021123222541064024
#             z: -0.0020183396991342306
#             w: 0.99999570846557617
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "gpe"
#       value {
#         parent_frame_name: "odom"
#         parent_tform_child {
#           position {
#             x: 9.9505710601806641
#             y: -0.69856929779052734
#             z: 1.6343004703521729
#           }
#           rotation {
#             x: -0.001071372302249074
#             y: 0.004742905031889677
#             z: -5.0814769565477036e-006
#             w: 0.99998819828033447
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "flat_body"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#           }
#           rotation {
#             x: -0.0020200170110911131
#             y: 0.0048573026433587074
#             z: -9.8105201686848886e-006
#             w: 0.99998617172241211
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "body"
#       value {
#         parent_tform_child {
#           position {
#           }
#           rotation {
#             w: 1
#           }
#         }
#       }
#     }
#   }
#   velocity_of_body_in_vision {
#     linear {
#       x: 0.00012073283141944557
#       y: -8.75118566909805e-005
#       z: 0.00062730512581765652
#     }
#     angular {
#       x: -0.0016344825271517038
#       y: -0.000841426313854754
#       z: 0.0019754853565245867
#     }
#   }
#   velocity_of_body_in_odom {
#     linear {
#       x: -0.00014046917203813791
#       y: -5.0041518989019096e-005
#       z: 0.00062731257639825344
#     }
#     angular {
#       x: 0.00023087603040039539
#       y: 0.0018237937474623322
#       z: 0.0019754853565245867
#     }
#   }
# }
# behavior_fault_state {
# }
# foot_state {
#   foot_position_rt_body {
#     x: 0.33219766616821289
#     y: 0.23390862345695496
#     z: -0.089339576661586761
#   }
#   contact: CONTACT_LOST
#   terrain {
#     ground_mu_est: 0.60000002384185791
#     frame_name: "odom"
#     foot_slip_distance_rt_frame {
#       x: 0.00015705529949627817
#       y: 0.0006206952384673059
#       z: -1.3632671880259295e-006
#     }
#     foot_slip_velocity_rt_frame {
#       x: -0.013501920737326145
#       y: 0.019637828692793846
#       z: 0.00016095665341708809
#     }
#     ground_contact_normal_rt_frame {
#       x: 0.011048624292016029
#       y: -0.00059940095525234938
#       z: 0.99993884563446045
#     }
#   }
# }
# foot_state {
#   foot_position_rt_body {
#     x: 0.33134075999259949
#     y: -0.23408195376396179
#     z: -0.090036898851394653
#   }
#   contact: CONTACT_LOST
#   terrain {
#     ground_mu_est: 0.60000002384185791
#     frame_name: "odom"
#     foot_slip_distance_rt_frame {
#       x: 0.00081239000428467989
#       y: 0.0018277773633599281
#       z: -7.880832527007442e-006
#     }
#     foot_slip_velocity_rt_frame {
#       x: -0.0066918432712554932
#       y: 0.020564336329698563
#       z: 8.6266991274897009e-005
#     }
#     ground_contact_normal_rt_frame {
#       x: 0.011048624292016029
#       y: -0.00059940095525234938
#       z: 0.99993884563446045
#     }
#   }
# }
# foot_state {
#   foot_position_rt_body {
#     x: -0.26043903827667236
#     y: 0.23761707544326782
#     z: -0.079645127058029175
#   }
#   contact: CONTACT_LOST
#   terrain {
#     ground_mu_est: 0.60000002384185791
#     frame_name: "odom"
#     foot_slip_distance_rt_frame {
#       x: -0.00539288017898798
#       y: 0.0066286344081163406
#       z: 6.51453374302946e-005
#     }
#     foot_slip_velocity_rt_frame {
#       x: -0.063737280666828156
#       y: 0.047693200409412384
#       z: 0.00074815802508965135
#     }
#     ground_contact_normal_rt_frame {
#       x: 0.011205735616385937
#       y: -0.00071054813452064991
#       z: 0.99993693828582764
#     }
#   }
# }
# foot_state {
#   foot_position_rt_body {
#     x: -0.26268559694290161
#     y: -0.237673819065094
#     z: -0.08013586699962616
#   }
#   contact: CONTACT_LOST
#   terrain {
#     ground_mu_est: 0.60000002384185791
#     frame_name: "odom"
#     foot_slip_distance_rt_frame {
#       x: 0.0027480477001518011
#       y: 0.0013373723486438394
#       z: -1.3838533050147817e-005
#     }
#     foot_slip_velocity_rt_frame {
#       x: 0.00072581280255690217
#       y: -0.010501567274332047
#       z: 1.134310969064245e-005
#     }
#     ground_contact_normal_rt_frame {
#       x: 0.0043632695451378822
#       y: 0.0013817817671224475
#       z: 0.99998950958251953
#     }
#   }
# }
# manipulator_state {
#   gripper_open_percentage: 0.73604583740234375
#   estimated_end_effector_force_in_hand {
#     x: 9.2004299163818359
#     y: -1.8288983106613159
#     z: 18.975244522094727
#   }
#   stow_state: STOWSTATE_STOWED
#   velocity_of_hand_in_vision {
#     linear {
#       x: -0.0010874441359192133
#       y: 0.003779255785048008
#       z: -0.0073876837268471718
#     }
#     angular {
#       x: 0.0002261913032270968
#       y: -0.013192368671298027
#       z: -0.018536217510700226
#     }
#   }
#   velocity_of_hand_in_odom {
#     linear {
#       x: 0.0037315108347684145
#       y: -0.0012414061930030584
#       z: -0.0073876758106052876
#     }
#     angular {
#       x: -0.011006133630871773
#       y: 0.0072769983671605587
#       z: -0.018536217510700226
#     }
#   }
#   carry_state: CARRY_STATE_NOT_CARRIABLE
# }
# terrain_state {
# }

# %% [markdown]
# ### Camera Images

# %%
from bosdyn.client.image import ImageClient

image_client = robot.ensure_client(ImageClient.default_service_name)
sources = image_client.list_image_sources()
[source.name for source in sources]
# Out:
# ['back_depth',
#  'back_depth_in_visual_frame',
#  'back_fisheye_image',
#  'frontleft_depth',
#  'frontleft_depth_in_visual_frame',
#  'frontleft_fisheye_image',
#  'frontright_depth',
#  'frontright_depth_in_visual_frame',
#  'frontright_fisheye_image',
#  'hand_color_image',
#  'hand_color_in_hand_depth_frame',
#  'hand_depth',
#  'hand_depth_in_hand_color_frame',
#  'hand_image',
#  'left_depth',
#  'left_depth_in_visual_frame',
#  'left_fisheye_image',
#  'right_depth',
#  'right_depth_in_visual_frame',
#  'right_fisheye_image']

# %%
image_response = image_client.get_image_from_sources(["hand_color_image"])[0] # see options for camera aboove 
from PIL import Image
import io
image = Image.open(io.BytesIO(image_response.shot.image.data))
image.show()

# %% [markdown]
# ### Software E-Stop

# %%
# creating a client to the E-Stop service and requesting status
estop_client = robot.ensure_client('estop')
estop_client.get_status()
# Out:
# endpoints {
#   endpoint {
#     role: "PDB_rooted"
#     name: "EStop"
#     unique_id: "3"
#     timeout {
#       seconds: 5
#     }
#     cut_power_timeout {
#       seconds: 13
#     }
#   }
#   stop_level: ESTOP_LEVEL_CUT
#   time_since_valid_response {
#     seconds: 34
#     nanos: 92179968
#   }
# }
# stop_level: ESTOP_LEVEL_CUT
# stop_level_details: "Endpoint has timed out"

# %%
# create and register an E-Stop Endpoint
estop_endpoint = bosdyn.client.estop.EstopEndpoint(client=estop_client, name='my_estop', estop_timeout=9.0)
estop_endpoint.force_simple_setup()
estop_client.get_status()
# Out:
# endpoints {
#   endpoint {
#     role: "PDB_rooted"
#     name: "my_estop"
#     unique_id: "4"
#     timeout {
#       seconds: 9
#     }
#     cut_power_timeout {
#       seconds: 17
#     }
#   }
#   stop_level: ESTOP_LEVEL_CUT
#   time_since_valid_response {
#   }
# }
# stop_level: ESTOP_LEVEL_CUT
# stop_level_details: "Endpoint requested stop"

# %%
# clear e-stop
estop_keep_alive = bosdyn.client.estop.EstopKeepAlive(estop_endpoint)
estop_client.get_status()
# Out:
# endpoints {
#   endpoint {
#     role: "PDB_rooted"
#     name: "my_estop"
#     unique_id: "4"
#     timeout {
#       seconds: 9
#     }
#     cut_power_timeout {
#       seconds: 17
#     }
#   }
#   stop_level: ESTOP_LEVEL_NONE
#   time_since_valid_response {
#     nanos: 3000064
#   }
# }
# stop_level: ESTOP_LEVEL_NONE

# %% [markdown]
# ### Taking ownership (Lease)

# %%
lease_client = robot.ensure_client('lease')
lease_client.list_leases()
# Out:
# [resource: "all-leases"
# lease {
#   resource: "all-leases"
#   epoch: "gGimdbRXEewCNoFQ"
#   sequence: 7
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK2450836W2:23924"
# }
# , resource: "arm"
# lease {
#   resource: "arm"
#   epoch: "gGimdbRXEewCNoFQ"
#   sequence: 7
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK2450836W2:23924"
# }
# , resource: "body"
# lease {
#   resource: "body"
#   epoch: "gGimdbRXEewCNoFQ"
#   sequence: 7
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK2450836W2:23924"
# }
# , resource: "fan"
# lease {
#   resource: "fan"
#   epoch: "gGimdbRXEewCNoFQ"
#   sequence: 7
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK2450836W2:23924"
# }
# , resource: "full-arm"
# lease {
#   resource: "full-arm"
#   epoch: "gGimdbRXEewCNoFQ"
#   sequence: 7
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK2450836W2:23924"
# }
# , resource: "gripper"
# lease {
#   resource: "gripper"
#   epoch: "gGimdbRXEewCNoFQ"
#   sequence: 7
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK2450836W2:23924"
# }
# , resource: "mobility"
# lease {
#   resource: "mobility"
#   epoch: "gGimdbRXEewCNoFQ"
#   sequence: 7
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK2450836W2:23924"
# }
# ]

# %%
lease = lease_client.acquire()
lease_keep_alive = bosdyn.client.lease.LeaseKeepAlive(lease_client)
lease_client.list_leases()
# Out:
# [resource: "all-leases"
# lease {
#   resource: "all-leases"
#   epoch: "gGimdbRXEewCNoFQ"
#   sequence: 9
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK2450836W2:23924"
# }
# , resource: "arm"
# lease {
#   resource: "arm"
#   epoch: "gGimdbRXEewCNoFQ"
#   sequence: 9
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK2450836W2:23924"
# }
# , resource: "body"
# lease {
#   resource: "body"
#   epoch: "gGimdbRXEewCNoFQ"
#   sequence: 9
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK2450836W2:23924"
# }
# , resource: "fan"
# lease {
#   resource: "fan"
#   epoch: "gGimdbRXEewCNoFQ"
#   sequence: 9
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK2450836W2:23924"
# }
# , resource: "full-arm"
# lease {
#   resource: "full-arm"
#   epoch: "gGimdbRXEewCNoFQ"
#   sequence: 9
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK2450836W2:23924"
# }
# , resource: "gripper"
# lease {
#   resource: "gripper"
#   epoch: "gGimdbRXEewCNoFQ"
#   sequence: 9
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK2450836W2:23924"
# }
# , resource: "mobility"
# lease {
#   resource: "mobility"
#   epoch: "gGimdbRXEewCNoFQ"
#   sequence: 9
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK2450836W2:23924"
# }
# ]

# %%
lease = lease_client.return_lease(lease)
# Out:
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# ...
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)
# Generic exception for  during check-in:
# No lease for resource "body"
#     (resuming check-in)

# %% [markdown]
# ### Power on

# %%
robot.power_on(timeout_sec=20)
robot.is_powered_on()
# Out:
# True

# %% [markdown]
# ### Timesync

# %%
# timesync
robot.time_sync.wait_for_sync()

# %% [markdown]
# ### Commanding the robot

# %%
from bosdyn.client.robot_command import RobotCommandClient, blocking_stand, blocking_sit, blocking_selfright
command_client = robot.ensure_client(RobotCommandClient.default_service_name)

# %%
# Stand
blocking_stand(command_client, timeout_sec=10)

# %%
# Sit
blocking_sit(command_client, timeout_sec=10)

# %% [markdown]
# In addition, the stand command can be modified to control the height of the body as well as the orientation of the body with respect to the footprint frame. The footprint frame is a gravity aligned frame with its origin located at the geometric center of the feet. The Z axis up, and the X axis is forward.

# %%
# Rotate around the z axis
from bosdyn.geometry import EulerZXY
footprint_R_body = EulerZXY(yaw=0.1, roll=-0.5, pitch=0.1)

from bosdyn.client.robot_command import RobotCommandBuilder
cmd = RobotCommandBuilder.synchro_stand_command(footprint_R_body=footprint_R_body)
command_client.robot_command(cmd)
# Out:
# 5472

# %% [markdown]
# ### Power off

# %% [markdown]
# Power off the robot using the power_off command. Note the preferred method is with cut_immediately=False where Spot will come to a stop and sit down gently before powering off. The other power off option cuts motor power immediately, which causes the robot to collapse.

# %%
robot.power_off(cut_immediately=False)
# Out:
# Unclassified exception: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNKNOWN
# 	details = "Stream removed"
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:192.168.80.3:443 {created_time:"2023-01-25T14:52:41.434740804+00:00", grpc_status:2, grpc_message:"Stream removed"}"
# >
# Generic exception for  during check-in:
# RpcError: An error occurred trying to reach a service on the robot.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# ...
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
