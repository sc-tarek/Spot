# %% [markdown]
# ## Setup and Command Spot to Move

# %% [markdown]
# #### Create objects

# %% [markdown]
# All Boston Dynamics API programs start by creating an SDK object with a client name argument. The client name is used to help with debugging, and does not have any semantic information - so use whatever string is helpful for you.

# %%
import bosdyn.client

sdk = bosdyn.client.create_standard_sdk('understanding-spot')

# %% [markdown]
# To retrieve the robot id like we did in Spot Python SDK Quickstart we’ll first need to create a robot object, using its network address as an argument. In this example, we only create one robot object, but it is possible to create and control multiple robots in the same program with the Boston Dynamics API.

# %%
robot = sdk.create_robot('192.168.80.3')

# %% [markdown]
# #### Services and Authentication

# %% [markdown]
# -- Need to be on the Spot Wifi for this step --
#
# Before robot state can be retrieved, you need to authenticate to the robot. The majority of services require the user to be authenticated - this prevents random network attackers from being able to control the robot or intercept information which might be sensitive.

# %%
robot.authenticate('user', 'hhe262iz9zez')

# %% [markdown]
# Obtain information about Spot:

# %%
state_client = robot.ensure_client('robot-state')

# %%
state_client.get_robot_state()
# Out:
# power_state {
#   motor_power_state: STATE_OFF
#   shore_power_state: STATE_OFF_SHORE_POWER
#   robot_power_state: ROBOT_POWER_STATE_ON
#   payload_ports_power_state: PAYLOAD_PORTS_POWER_STATE_ON
#   wifi_radio_power_state: WIFI_RADIO_POWER_STATE_ON
#   locomotion_charge_percentage {
#     value: 16
#   }
#   locomotion_estimated_runtime {
#     seconds: 948
#     nanos: 557373046
#   }
# }
# battery_states {
#   identifier: "a2-22b14-001e"
#   charge_percentage {
#     value: 16
#   }
#   estimated_runtime {
#     seconds: 948
#     nanos: 557373046
#   }
#   current {
#     value: -4.1600003242492676
#   }
#   voltage {
#     value: 47.6140022277832
#   }
#   temperatures: 36.437038421630859
#   temperatures: 36.144443511962891
#   temperatures: 36.181480407714844
#   temperatures: 35.911109924316406
#   temperatures: 35.374073028564453
#   temperatures: 36.355556488037109
#   temperatures: 35.548149108886719
#   temperatures: 35.629631042480469
#   temperatures: 35.962963104248047
#   temperatures: 35.974075317382812
#   status: STATUS_DISCHARGING
# }
# comms_states {
#   timestamp {
#     seconds: 1674654293
#     nanos: 85860473
#   }
#   wifi_state {
#     current_mode: MODE_ACCESS_POINT
#   }
# }
# system_fault_state {
# }
# estop_states {
#   timestamp {
#     seconds: 1674654293
#     nanos: 474210048
#   }
#   name: "hardware_estop"
#   type: TYPE_HARDWARE
#   state: STATE_NOT_ESTOPPED
# }
# estop_states {
#   timestamp {
#     seconds: 1674654293
#     nanos: 474210048
#   }
#   name: "payload_estop"
#   type: TYPE_HARDWARE
#   state: STATE_NOT_ESTOPPED
# }
# estop_states {
#   timestamp {
#     seconds: 1674654293
#     nanos: 474210048
#   }
#   name: "software_estop"
#   type: TYPE_SOFTWARE
#   state: STATE_ESTOPPED
# }
# kinematic_state {
#   joint_states {
#     name: "fl.hx"
#     position {
#       value: 0.54634028673172
#     }
#     velocity {
#       value: -0.0035324234049767256
#     }
#     acceleration {
#       value: -2.1749072074890137
#     }
#     load {
#       value: 1.4804993867874146
#     }
#   }
#   joint_states {
#     name: "fl.hy"
#     position {
#       value: 1.2132192850112915
#     }
#     velocity {
#       value: -0.00583389587700367
#     }
#     acceleration {
#       value: 2.3025453090667725
#     }
#     load {
#       value: -0.70996379852294922
#     }
#   }
#   joint_states {
#     name: "fl.kn"
#     position {
#       value: -2.7833738327026367
#     }
#     velocity {
#       value: -0.014318061992526054
#     }
#     acceleration {
#       value: -4.9378705024719238
#     }
#     load {
#       value: -0.60842782258987427
#     }
#   }
#   joint_states {
#     name: "fr.hx"
#     position {
#       value: -0.52403146028518677
#     }
#     velocity {
#       value: 0.0042635262943804264
#     }
#     acceleration {
#       value: 1.8698556423187256
#     }
#     load {
#       value: -1.9153854846954346
#     }
#   }
#   joint_states {
#     name: "fr.hy"
#     position {
#       value: 1.2406288385391235
#     }
#     velocity {
#       value: -0.0043883193284273148
#     }
#     acceleration {
#       value: 1.1795101165771484
#     }
#     load {
#       value: -0.55851632356643677
#     }
#   }
#   joint_states {
#     name: "fr.kn"
#     position {
#       value: -2.795184850692749
#     }
#     velocity {
#       value: 0.06357274204492569
#     }
#     acceleration {
#       value: -1.9937670230865479
#     }
#     load {
#       value: -0.2069815993309021
#     }
#   }
#   joint_states {
#     name: "hl.hx"
#     position {
#       value: 0.55188214778900146
#     }
#     velocity {
#       value: -0.0089853713288903236
#     }
#     acceleration {
#       value: -2.72847056388855
#     }
#     load {
#       value: 0.353721559047699
#     }
#   }
#   joint_states {
#     name: "hl.hy"
#     position {
#       value: 1.2544550895690918
#     }
#     velocity {
#       value: 0.0082139838486909866
#     }
#     acceleration {
#       value: 1.1724827289581299
#     }
#     load {
#       value: 1.6560392379760742
#     }
#   }
#   joint_states {
#     name: "hl.kn"
#     position {
#       value: -2.7975559234619141
#     }
#     velocity {
#       value: 0.0031507089734077454
#     }
#     acceleration {
#       value: -0.92185401916503906
#     }
#     load {
#       value: 0.032331462949514389
#     }
#   }
#   joint_states {
#     name: "hr.hx"
#     position {
#       value: -0.57313227653503418
#     }
#     velocity {
#       value: 0.0011492212070152164
#     }
#     acceleration {
#       value: 1.0173430442810059
#     }
#     load {
#       value: -0.81887316703796387
#     }
#   }
#   joint_states {
#     name: "hr.hy"
#     position {
#       value: 1.2512960433959961
#     }
#     velocity {
#       value: -0.005335705354809761
#     }
#     acceleration {
#       value: -0.80762171745300293
#     }
#     load {
#       value: 0.46741628646850586
#     }
#   }
#   joint_states {
#     name: "hr.kn"
#     position {
#       value: -2.8002676963806152
#     }
#     velocity {
#       value: -0.0026314477436244488
#     }
#     acceleration {
#       value: -2.2673869132995605
#     }
#     load {
#       value: -0.12317293137311935
#     }
#   }
#   joint_states {
#     name: "arm0.sh0"
#     position {
#       value: -0.021048307418823242
#     }
#     velocity {
#       value: 0.0033628481905907393
#     }
#     acceleration {
#       value: -0.28705081343650818
#     }
#     load {
#       value: 0.91865795850753784
#     }
#   }
#   joint_states {
#     name: "arm0.sh1"
#     position {
#       value: -3.1333181858062744
#     }
#     velocity {
#       value: 0.00076183484634384513
#     }
#     acceleration {
#       value: 0.33511215448379517
#     }
#     load {
#       value: -0.21739837527275085
#     }
#   }
#   joint_states {
#     name: "arm0.hr0"
#     position {
#     }
#     velocity {
#     }
#     acceleration {
#     }
#     load {
#     }
#   }
#   joint_states {
#     name: "arm0.el0"
#     position {
#       value: 3.1309888362884521
#     }
#     velocity {
#       value: 0.0069123418070375919
#     }
#     acceleration {
#       value: 1.5746355056762695
#     }
#     load {
#       value: 0.077330432832241058
#     }
#   }
#   joint_states {
#     name: "arm0.el1"
#     position {
#       value: 1.5702327489852905
#     }
#     velocity {
#       value: -0.0083914464339613914
#     }
#     acceleration {
#       value: 0.22288379073143005
#     }
#     load {
#       value: -0.067668221890926361
#     }
#   }
#   joint_states {
#     name: "arm0.wr0"
#     position {
#       value: -0.014945387840270996
#     }
#     velocity {
#       value: 5.692343620467e-005
#     }
#     acceleration {
#       value: 0.88542699813842773
#     }
#     load {
#       value: -0.055101249366998672
#     }
#   }
#   joint_states {
#     name: "arm0.wr1"
#     position {
#       value: -1.5682578086853027
#     }
#     velocity {
#       value: 0.0080688139423727989
#     }
#     acceleration {
#       value: 1.2411633729934692
#     }
#     load {
#       value: 0.23979827761650085
#     }
#   }
#   joint_states {
#     name: "arm0.f1x"
#     position {
#       value: -0.012358903884887695
#     }
#     velocity {
#       value: 0.0031182076781988144
#     }
#     acceleration {
#       value: -1.1915663480758667
#     }
#     load {
#       value: -7.7577366027981043e-005
#     }
#   }
#   acquisition_timestamp {
#     seconds: 1674654293
#     nanos: 474210048
#   }
#   transforms_snapshot {
#     child_to_parent_edge_map {
#       key: "vision"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: 0.0030964910984039307
#             y: 0.0032402202486991882
#             z: 0.001773834228515625
#           }
#           rotation {
#             x: -0.00059880490880459547
#             y: 0.00574595108628273
#             z: -0.00035946097341366112
#             w: 0.99998337030410767
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "odom"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: -0.14696976542472839
#             y: -0.0812409296631813
#             z: -1.8868533372879028
#           }
#           rotation {
#             x: -0.0041418634355068207
#             y: 0.0040273414924740791
#             z: -0.6410941481590271
#             w: 0.76744049787521362
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "link_wr1"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: 0.35662144422531128
#             y: -0.0013603726401925087
#             z: 0.266740083694458
#           }
#           rotation {
#             x: 0.00098371261265128851
#             y: -0.0011866504792124033
#             z: -0.017994699999690056
#             w: 0.99983686208724976
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "hand"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#             x: 0.55206423997879028
#             y: -0.0083981286734342575
#             z: 0.26719722151756287
#           }
#           rotation {
#             x: 0.00098371261265128851
#             y: -0.0011866504792124033
#             z: -0.017994699999690056
#             w: 0.99983686208724976
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "gpe"
#       value {
#         parent_frame_name: "odom"
#         parent_tform_child {
#           position {
#             x: -0.055431872606277466
#             y: 0.13733305037021637
#             z: 1.8897039890289307
#           }
#           rotation {
#             x: 0.012466439045965672
#             y: -0.093162350356578827
#             z: -0.0011665681377053261
#             w: 0.99557220935821533
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "flat_body"
#       value {
#         parent_frame_name: "body"
#         parent_tform_child {
#           position {
#           }
#           rotation {
#             x: -0.00059675844386219978
#             y: 0.0057461629621684551
#             z: -3.4615097774803871e-006
#             w: 0.99998331069946289
#           }
#         }
#       }
#     }
#     child_to_parent_edge_map {
#       key: "body"
#       value {
#         parent_tform_child {
#           position {
#           }
#           rotation {
#             w: 1
#           }
#         }
#       }
#     }
#   }
#   velocity_of_body_in_vision {
#     linear {
#       x: -0.00038268658681772649
#       y: -0.00038137490628287196
#       z: -0.00020391307771205902
#     }
#     angular {
#       x: 0.00083675049245357513
#       y: 0.0052011660300195217
#       z: -0.00085639022290706635
#     }
#   }
#   velocity_of_body_in_odom {
#     linear {
#       x: 0.00030686100944876671
#       y: -0.00044467105180956423
#       z: -0.00020391284488141537
#     }
#     angular {
#       x: -0.004967960063368082
#       y: 0.0017526098527014256
#       z: -0.00085639022290706635
#     }
#   }
# }
# behavior_fault_state {
# }
# foot_state {
#   foot_position_rt_body {
#     x: 0.36635640263557434
#     y: 0.23335453867912292
#     z: -0.079772263765335083
#   }
#   contact: CONTACT_LOST
# }
# foot_state {
#   foot_position_rt_body {
#     x: 0.36231246590614319
#     y: -0.23031614720821381
#     z: -0.081629395484924316
#   }
#   contact: CONTACT_LOST
# }
# foot_state {
#   foot_position_rt_body {
#     x: -0.23549982905387878
#     y: 0.23253418505191803
#     z: -0.076736651360988617
#   }
#   contact: CONTACT_LOST
# }
# foot_state {
#   foot_position_rt_body {
#     x: -0.23490926623344421
#     y: -0.23348903656005859
#     z: -0.071962118148803711
#   }
#   contact: CONTACT_LOST
# }
# manipulator_state {
#   gripper_open_percentage: 0.78719258308410645
#   estimated_end_effector_force_in_hand {
#     x: 14.688955307006836
#     y: -1.7789499759674072
#     z: 15.182923316955566
#   }
#   stow_state: STOWSTATE_STOWED
#   velocity_of_hand_in_vision {
#     linear {
#       x: 0.001698516309261322
#       y: -0.00020143165602348745
#       z: -0.0073696309700608253
#     }
#     angular {
#       x: 0.00062736985273659229
#       y: 0.012755692936480045
#       z: 0.002569596515968442
#     }
#   }
#   velocity_of_hand_in_odom {
#     linear {
#       x: 0.00050167529843747616
#       y: 0.0016351921949535608
#       z: -0.0073696300387382507
#     }
#     angular {
#       x: -0.012438328936696053
#       y: 0.002896416001021862
#       z: 0.002569596515968442
#     }
#   }
#   carry_state: CARRY_STATE_NOT_CARRIABLE
# }
# terrain_state {
# }

# %% [markdown]
# ### Capture and View Camera Images

# %%
from bosdyn.client.image import ImageClient

image_client = robot.ensure_client(ImageClient.default_service_name)
sources = image_client.list_image_sources()
[source.name for source in sources]
# Out:
# ['back_depth',
#  'back_depth_in_visual_frame',
#  'back_fisheye_image',
#  'frontleft_depth',
#  'frontleft_depth_in_visual_frame',
#  'frontleft_fisheye_image',
#  'frontright_depth',
#  'frontright_depth_in_visual_frame',
#  'frontright_fisheye_image',
#  'hand_color_image',
#  'hand_color_in_hand_depth_frame',
#  'hand_depth',
#  'hand_depth_in_hand_color_frame',
#  'hand_image',
#  'left_depth',
#  'left_depth_in_visual_frame',
#  'left_fisheye_image',
#  'right_depth',
#  'right_depth_in_visual_frame',
#  'right_fisheye_image']

# %%
image_response = image_client.get_image_from_sources(["hand_color_image"])[0] # see options for camera aboove 
from PIL import Image
import io
image = Image.open(io.BytesIO(image_response.shot.image.data))
image.show()

# %% [markdown]
# ### Configuring “Motor Power Authority” (software E-Stop)

# %%
# creating a client to the E-Stop service and requesting status
estop_client = robot.ensure_client('estop')
estop_client.get_status()
# Out:
# stop_level: ESTOP_LEVEL_CUT
# stop_level_details: "Not all endpoints are registered"

# %%
# create and register an E-Stop Endpoint
estop_endpoint = bosdyn.client.estop.EstopEndpoint(client=estop_client, name='my_estop', estop_timeout=9.0)
estop_endpoint.force_simple_setup()
estop_client.get_status()
# Out:
# endpoints {
#   endpoint {
#     role: "PDB_rooted"
#     name: "my_estop"
#     unique_id: "5"
#     timeout {
#       seconds: 9
#     }
#     cut_power_timeout {
#       seconds: 17
#     }
#   }
#   stop_level: ESTOP_LEVEL_CUT
#   time_since_valid_response {
#   }
# }
# stop_level: ESTOP_LEVEL_CUT
# stop_level_details: "Endpoint requested stop"

# %%
# clear e-stop
estop_keep_alive = bosdyn.client.estop.EstopKeepAlive(estop_endpoint)
estop_client.get_status()
# Out:
# endpoints {
#   endpoint {
#     role: "PDB_rooted"
#     name: "my_estop"
#     unique_id: "5"
#     timeout {
#       seconds: 9
#     }
#     cut_power_timeout {
#       seconds: 17
#     }
#   }
#   stop_level: ESTOP_LEVEL_NONE
#   time_since_valid_response {
#     nanos: 3000064
#   }
# }
# stop_level: ESTOP_LEVEL_NONE
# bosdyn.api.EstopCheckInResponse (EndpointUnknownError): The endpoint specified in the request is not registered.

# %% [markdown]
# ### Taking ownership of Spot (Leases)

# %%
lease_client = robot.ensure_client('lease')
lease_client.list_leases()
# Out:
# [resource: "all-leases"
# lease {
#   resource: "all-leases"
#   epoch: "KsxuRazVOfrwXobi"
#   sequence: 0
#   client_names: "root"
# }
# lease_owner {
# }
# , resource: "arm"
# lease {
#   resource: "arm"
#   epoch: "KsxuRazVOfrwXobi"
#   sequence: 0
#   client_names: "root"
# }
# lease_owner {
# }
# , resource: "body"
# lease {
#   resource: "body"
#   epoch: "KsxuRazVOfrwXobi"
#   sequence: 0
#   client_names: "root"
# }
# lease_owner {
# }
# , resource: "fan"
# lease {
#   resource: "fan"
#   epoch: "KsxuRazVOfrwXobi"
#   sequence: 0
#   client_names: "root"
# }
# lease_owner {
# }
# , resource: "full-arm"
# lease {
#   resource: "full-arm"
#   epoch: "KsxuRazVOfrwXobi"
#   sequence: 0
#   client_names: "root"
# }
# lease_owner {
# }
# , resource: "gripper"
# lease {
#   resource: "gripper"
#   epoch: "KsxuRazVOfrwXobi"
#   sequence: 0
#   client_names: "root"
# }
# lease_owner {
# }
# , resource: "mobility"
# lease {
#   resource: "mobility"
#   epoch: "KsxuRazVOfrwXobi"
#   sequence: 0
#   client_names: "root"
# }
# lease_owner {
# }
# ]

# %%
lease = lease_client.return_lease(lease)
# Out:
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)
# Generic exception for  during check-in:
# bosdyn.api.RetainLeaseResponse (LeaseUseError):
#     (resuming check-in)

# %%
lease = lease_client.acquire()
lease_keep_alive = bosdyn.client.lease.LeaseKeepAlive(lease_client)
lease_client.list_leases()
# Out:
# [resource: "all-leases"
# lease {
#   resource: "all-leases"
#   epoch: "KsxuRazVOfrwXobi"
#   sequence: 1
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK3338147W1:66208"
# }
# , resource: "arm"
# lease {
#   resource: "arm"
#   epoch: "KsxuRazVOfrwXobi"
#   sequence: 1
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK3338147W1:66208"
# }
# , resource: "body"
# lease {
#   resource: "body"
#   epoch: "KsxuRazVOfrwXobi"
#   sequence: 1
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK3338147W1:66208"
# }
# , resource: "fan"
# lease {
#   resource: "fan"
#   epoch: "KsxuRazVOfrwXobi"
#   sequence: 1
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK3338147W1:66208"
# }
# , resource: "full-arm"
# lease {
#   resource: "full-arm"
#   epoch: "KsxuRazVOfrwXobi"
#   sequence: 1
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK3338147W1:66208"
# }
# , resource: "gripper"
# lease {
#   resource: "gripper"
#   epoch: "KsxuRazVOfrwXobi"
#   sequence: 1
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK3338147W1:66208"
# }
# , resource: "mobility"
# lease {
#   resource: "mobility"
#   epoch: "KsxuRazVOfrwXobi"
#   sequence: 1
#   client_names: "root"
# }
# lease_owner {
#   client_name: "understanding-spotDK3338147W1:66208"
# }
# ]

# %%
robot.power_on(timeout_sec=20)
#robot.is_powered_on()

# %%
# timesync
robot.time_sync.wait_for_sync()

# %% [markdown]
# ### Commanding the robot

# %%
from bosdyn.client.robot_command import RobotCommandClient, blocking_stand, blocking_sit, blocking_selfright
command_client = robot.ensure_client(RobotCommandClient.default_service_name)

# %%
# Stand
blocking_stand(command_client, timeout_sec=10)

# %%
# Sit
blocking_sit(command_client, timeout_sec=10)

# %% [markdown]
# In addition, the stand command can be modified to control the height of the body as well as the orientation of the body with respect to the footprint frame. The footprint frame is a gravity aligned frame with its origin located at the geometric center of the feet. The Z axis up, and the X axis is forward.

# %%
# Rotate around the z axis:

from bosdyn.geometry import EulerZXY
footprint_R_body = EulerZXY(yaw=0.5, roll=0, pitch=0)

from bosdyn.client.robot_command import RobotCommandBuilder
cmd = RobotCommandBuilder.synchro_stand_command(footprint_R_body=footprint_R_body)
command_client.robot_command(cmd)
# Out:
# 27

# %% [markdown]
# ### Powering off the robot

# %% [markdown]
# Power off the robot using the power_off command. Note the preferred method is with cut_immediately=False where Spot will come to a stop and sit down gently before powering off. The other power off option cuts motor power immediately, which causes the robot to collapse.

# %%
robot.power_off(cut_immediately=False)
# Out:
# Unclassified exception: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNKNOWN
# 	details = "Stream removed"
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:192.168.80.3:443 {created_time:"2023-01-25T14:52:41.434740804+00:00", grpc_status:2, grpc_message:"Stream removed"}"
# >
# Generic exception for  during check-in:
# RpcError: An error occurred trying to reach a service on the robot.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# ...
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
# Generic exception for  during check-in:
# UnableToConnectToRobotError: The robot may be offline or otherwise unreachable.
#     (resuming check-in)
